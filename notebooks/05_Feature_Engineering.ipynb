# %% [markdown]
# # 05 Feature Engineering
#
# This notebook summarizes engineered variables used by match prediction, sponsor ROI prediction, FanScore, and panel dashboarding.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('..').resolve()
df = pd.read_csv(ROOT / 'data' / 'modeling_dataset.csv')
features = ['elo_diff', 'market_value_diff_m', 'coach_exp_diff', 'core_rating_diff', 'fan_score', 'a_sponsor_power_index', 'sponsor_roi']
df[features].describe().round(3)
