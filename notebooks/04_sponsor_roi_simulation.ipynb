# %% [markdown]
# # 04 Sponsor ROI Simulation
#
# This notebook documents sponsor investment, FanScore, exposure, and ROI simulation logic.

# %%
from pathlib import Path
import sys
import pandas as pd

ROOT = Path('..').resolve()
sys.path.append(str(ROOT / 'src'))
from sponsor_roi import compute_roi_score

panel = pd.read_csv(ROOT / 'data' / 'panel_dataset.csv')
panel['roi_formula_score'] = compute_roi_score(panel)
panel[['team', 'sponsor', 'fan_score_panel', 'sponsor_power_index', 'predicted_roi', 'roi_formula_score']].head()
